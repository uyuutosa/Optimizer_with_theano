# %% [markdown]
# モジュールのインポート

# %%
from numpy import *
from pylab import *
import Optimizer_with_theano as op 
# %matplotlib inline

# %% [markdown]
# yの時系列データをシーケンシャルに10個から、1時刻あとのデータ予測する学習器をつくる

# %% [markdown]
# # データの生成

# %%
def gen_dataset(v, length):
    v = v.flatten()
    idx = arange(v.size)
    idx = idx[:, None] + arange(length+1)
    idx = idx[:-length]
    xidx = idx[:, :-1]
    yidx = idx[:, -1]
    x_idx_f = xidx.flatten()
    y_idx_f = yidx.flatten()
    x = v[x_idx_f].reshape(-1, 1, 1, length)
    y = v[y_idx_f][:, None]
    return x, y, xidx, yidx

#v = zeros(1000)
#for i in range(10000):
#    v += sin(pi * arange(1000) / randint(10, 1000) + randint(0, 1000)) * arange(1000)[::-1]
v = sin(pi * arange(10000) / arange(1,10001)[::-1]*10) * arange(10000)[::-1]# + random(v.size) * arange(1000)[::-1] * 1
v = v[:-1000]
#v = sin(pi * arange(1000) / 30) * arange(1000)# + random(v.size) * arange(1000)[::-1] * 1
x, y, xidx, yidx = gen_dataset(v, 10)

# %%
#plot(xidx.flatten(),x.flatten())
plot(arange(v.size),v)
plot(yidx.flatten(),y.flatten())
#xlim(8500,9500)
xlabel("x")
ylabel("y")
legend(["data", "labels"])

# %% [markdown]
# データ及びラベルの形は以下の通りである。

# %%
print("Shape of x = {}".format(x.shape))
print("Shape of y = {}".format(y.shape))
# Out:
# Shape of x = (8990, 1, 1, 10)
# Shape of y = (8990, 1)

# %% [markdown]
# # 学習

# %% [markdown]
# ## UCNNの構築

# %% [markdown]
# theanoは1次元の畳込みが無いので、2次元畳込みを用いる

# %%
o = op.optimizer(n_batch=100)
o.set_data(x, y, test_size=0., is_shuffle=False)
o.set_variables()
o1 =  o.conv2d((1, 1, 1, 5), mode="same").relu()
o2 = o1.conv2d((1, 1, 1, 5), mode="same").relu()
o3 = o2.conv2d((1, 1, 1, 5), mode="same").relu()
o4 = o3.conv2d((1, 1, 1, 5), mode="same").relu()
o5 = o4.conv2d((1, 1, 1, 5), mode="same").relu() + o2 #前段の畳込み層をマージ
o6 = o5.conv2d((1, 1, 1, 5), mode="same").relu() + o1 #前段の畳込み層をマージ
o7 = o6.conv2d((1, 1, 1, 5), mode="same").relu()
o8 = o7.conv2d((1, 1, 1, 10), mode="valid")
o9 = o8.flatten()
o = o9.loss_mse()
# Out:
# (1, 1, 1)

# %%
o = op.optimizer(n_batch=1000)
o.set_data(x, y, test_size=0., is_shuffle=False)
o.set_variables()
o1  =  o.conv2d((1, 1, 1, 5), mode="same").relu()
o2  = o1.conv2d((1, 1, 1, 5), mode="same").relu()
o3  = o2.conv2d((1, 1, 1, 5), mode="same").relu()
o4  = o3.conv2d((1, 1, 1, 5), mode="same").relu()
o5  = o4.conv2d((1, 1, 1, 5), mode="same").relu() 
o6  = o5.conv2d((1, 1, 1, 5), mode="same").relu() 
o7  = o6.conv2d((1, 1, 1, 5), mode="same").relu() 
o8  = o7.conv2d((1, 1, 1, 5), mode="same").relu()  #前段の畳込み層をマージ
o9  = o8.conv2d((1, 1, 1, 5), mode="same").relu()  #前段の畳込み層をマージ
o10 = o9.conv2d((1, 1, 1, 5), mode="same").relu() 
o11 = o10.conv2d((1, 1, 1, 5), mode="same").relu() #+ o10
o12 = o11.conv2d((1, 1, 1, 5), mode="same").relu() #+ o9
o13 = o12.conv2d((1, 1, 1, 5), mode="same").relu() #+ o8
o14 = o13.conv2d((1, 1, 1, 5), mode="same").relu() #+ o7
o15 = o14.conv2d((1, 1, 1, 5), mode="same").relu() #+ o6
o16 = o15.conv2d((1, 1, 1, 5), mode="same").relu() #+ o5
o17 = o16.conv2d((1, 1, 1, 5), mode="same").relu() #+ o4
o18 = o17.conv2d((1, 1, 1, 5), mode="same").relu() + o3 #前段の畳込み層をマージ
o19 = o18.conv2d((1, 1, 1, 5), mode="same").relu() + o2 #前段の畳込み層をマージ
o20 = o19.conv2d((1, 1, 1, 5), mode="same").relu() 
o21 = o20.conv2d((1, 1, 1, 10), mode="valid")
o22 = o21.flatten()
o   = o22.loss_mse()
# Out:
# (1, 1, 1)

# %% [markdown]
# 最適化手法を定義し、最適化させる。

# %%
o = o.opt_Adam(0.01).compile()
o = o.optimize(10000000,10)
# Out:
# Epoch. 0: loss = 3.8524e+13, acc = 0.0000e+00, valid. loss = 1.9675e+10, valid. acc. = 0.0000e+00.
# Epoch. 10: loss = 1.5786e+10, acc = 0.0000e+00, valid. loss = 1.5539e+10, valid. acc. = 0.0000e+00.
# Epoch. 20: loss = 1.1667e+10, acc = 0.0000e+00, valid. loss = 1.1488e+10, valid. acc. = 0.0000e+00.
# Epoch. 30: loss = 8.0800e+09, acc = 0.0000e+00, valid. loss = 7.9004e+09, valid. acc. = 0.0000e+00.
# Epoch. 40: loss = 5.1516e+09, acc = 0.0000e+00, valid. loss = 5.0464e+09, valid. acc. = 0.0000e+00.
# Epoch. 50: loss = 3.0697e+09, acc = 0.0000e+00, valid. loss = 2.9849e+09, valid. acc. = 0.0000e+00.
# Epoch. 60: loss = 1.6792e+09, acc = 0.0000e+00, valid. loss = 1.6162e+09, valid. acc. = 0.0000e+00.
# Epoch. 70: loss = 8.1092e+08, acc = 0.0000e+00, valid. loss = 7.8192e+08, valid. acc. = 0.0000e+00.
# Epoch. 80: loss = 3.3685e+08, acc = 0.0000e+00, valid. loss = 3.1962e+08, valid. acc. = 0.0000e+00.
# Epoch. 90: loss = 1.1926e+08, acc = 0.0000e+00, valid. loss = 1.1236e+08, valid. acc. = 0.0000e+00.
# Epoch. 100: loss = 3.3298e+07, acc = 0.0000e+00, valid. loss = 3.1236e+07, valid. acc. = 0.0000e+00.
# Epoch. 110: loss = 1.3426e+07, acc = 0.0000e+00, valid. loss = 1.2950e+07, valid. acc. = 0.0000e+00.
# Epoch. 120: loss = 8.8326e+06, acc = 0.0000e+00, valid. loss = 8.7905e+06, valid. acc. = 0.0000e+00.
# Epoch. 130: loss = 8.2292e+06, acc = 0.0000e+00, valid. loss = 8.2211e+06, valid. acc. = 0.0000e+00.
# Epoch. 140: loss = 8.0152e+06, acc = 0.0000e+00, valid. loss = 8.0309e+06, valid. acc. = 0.0000e+00.
# Epoch. 150: loss = 7.9615e+06, acc = 0.0000e+00, valid. loss = 7.9388e+06, valid. acc. = 0.0000e+00.
# Epoch. 160: loss = 7.8728e+06, acc = 0.0000e+00, valid. loss = 7.8861e+06, valid. acc. = 0.0000e+00.
# Epoch. 170: loss = 7.8740e+06, acc = 0.0000e+00, valid. loss = 7.8596e+06, valid. acc. = 0.0000e+00.
# Epoch. 180: loss = 7.8860e+06, acc = 0.0000e+00, valid. loss = 7.8478e+06, valid. acc. = 0.0000e+00.
# Epoch. 190: loss = 7.8462e+06, acc = 0.0000e+00, valid. loss = 7.8391e+06, valid. acc. = 0.0000e+00.
# Epoch. 200: loss = 7.8336e+06, acc = 0.0000e+00, valid. loss = 7.8306e+06, valid. acc. = 0.0000e+00.
# Epoch. 210: loss = 7.8114e+06, acc = 0.0000e+00, valid. loss = 7.8219e+06, valid. acc. = 0.0000e+00.
# Epoch. 220: loss = 7.8021e+06, acc = 0.0000e+00, valid. loss = 7.8131e+06, valid. acc. = 0.0000e+00.
# Epoch. 230: loss = 7.8113e+06, acc = 0.0000e+00, valid. loss = 7.8043e+06, valid. acc. = 0.0000e+00.
# Epoch. 240: loss = 7.7920e+06, acc = 0.0000e+00, valid. loss = 7.7954e+06, valid. acc. = 0.0000e+00.
# Epoch. 250: loss = 7.7987e+06, acc = 0.0000e+00, valid. loss = 7.7864e+06, valid. acc. = 0.0000e+00.
# Epoch. 260: loss = 7.8074e+06, acc = 0.0000e+00, valid. loss = 7.7773e+06, valid. acc. = 0.0000e+00.
# Epoch. 270: loss = 7.7718e+06, acc = 0.0000e+00, valid. loss = 7.7682e+06, valid. acc. = 0.0000e+00.
# Epoch. 280: loss = 7.7432e+06, acc = 0.0000e+00, valid. loss = 7.7589e+06, valid. acc. = 0.0000e+00.
# Epoch. 290: loss = 7.7448e+06, acc = 0.0000e+00, valid. loss = 7.7495e+06, valid. acc. = 0.0000e+00.
# Epoch. 300: loss = 7.7385e+06, acc = 0.0000e+00, valid. loss = 7.7400e+06, valid. acc. = 0.0000e+00.
# Epoch. 310: loss = 7.7238e+06, acc = 0.0000e+00, valid. loss = 7.7300e+06, valid. acc. = 0.0000e+00.
# Epoch. 320: loss = 7.7413e+06, acc = 0.0000e+00, valid. loss = 7.7213e+06, valid. acc. = 0.0000e+00.
# Epoch. 330: loss = 7.7063e+06, acc = 0.0000e+00, valid. loss = 7.7408e+06, valid. acc. = 0.0000e+00.
# Epoch. 340: loss = 7.7206e+06, acc = 0.0000e+00, valid. loss = 7.7121e+06, valid. acc. = 0.0000e+00.
# Epoch. 350: loss = 7.6844e+06, acc = 0.0000e+00, valid. loss = 7.7052e+06, valid. acc. = 0.0000e+00.
# Epoch. 360: loss = 7.7078e+06, acc = 0.0000e+00, valid. loss = 7.7470e+06, valid. acc. = 0.0000e+00.
# Epoch. 370: loss = 7.6790e+06, acc = 0.0000e+00, valid. loss = 7.6942e+06, valid. acc. = 0.0000e+00.
# Epoch. 380: loss = 7.8053e+06, acc = 0.0000e+00, valid. loss = 8.0435e+06, valid. acc. = 0.0000e+00.
# Epoch. 390: loss = 7.7832e+06, acc = 0.0000e+00, valid. loss = 7.7656e+06, valid. acc. = 0.0000e+00.
# Epoch. 400: loss = 7.8930e+06, acc = 0.0000e+00, valid. loss = 8.0950e+06, valid. acc. = 0.0000e+00.
# Epoch. 410: loss = 7.6560e+06, acc = 0.0000e+00, valid. loss = 7.6653e+06, valid. acc. = 0.0000e+00.
# Epoch. 420: loss = 7.7008e+06, acc = 0.0000e+00, valid. loss = 7.7009e+06, valid. acc. = 0.0000e+00.
# Epoch. 430: loss = 7.8592e+06, acc = 0.0000e+00, valid. loss = 8.1810e+06, valid. acc. = 0.0000e+00.
# Epoch. 440: loss = 7.6170e+06, acc = 0.0000e+00, valid. loss = 7.7668e+06, valid. acc. = 0.0000e+00.
# Epoch. 450: loss = 7.6266e+06, acc = 0.0000e+00, valid. loss = 7.6469e+06, valid. acc. = 0.0000e+00.
# Epoch. 460: loss = 7.6159e+06, acc = 0.0000e+00, valid. loss = 7.5857e+06, valid. acc. = 0.0000e+00.
# Epoch. 470: loss = 7.5677e+06, acc = 0.0000e+00, valid. loss = 7.6095e+06, valid. acc. = 0.0000e+00.
# Epoch. 480: loss = 7.6269e+06, acc = 0.0000e+00, valid. loss = 7.6328e+06, valid. acc. = 0.0000e+00.
# Epoch. 490: loss = 7.5985e+06, acc = 0.0000e+00, valid. loss = 7.6113e+06, valid. acc. = 0.0000e+00.
# Epoch. 500: loss = 7.5706e+06, acc = 0.0000e+00, valid. loss = 7.5531e+06, valid. acc. = 0.0000e+00.
# Epoch. 510: loss = 7.5686e+06, acc = 0.0000e+00, valid. loss = 7.5517e+06, valid. acc. = 0.0000e+00.
# Epoch. 520: loss = 7.5791e+06, acc = 0.0000e+00, valid. loss = 7.5220e+06, valid. acc. = 0.0000e+00.
# Epoch. 530: loss = 7.5006e+06, acc = 0.0000e+00, valid. loss = 7.5157e+06, valid. acc. = 0.0000e+00.
# Epoch. 540: loss = 2.8615e+05, acc = 0.0000e+00, valid. loss = 1.2950e+05, valid. acc. = 0.0000e+00.
# Epoch. 550: loss = 2.3867e+04, acc = 0.0000e+00, valid. loss = 2.3988e+04, valid. acc. = 0.0000e+00.
# Epoch. 560: loss = 1.0322e+05, acc = 0.0000e+00, valid. loss = 8.4808e+04, valid. acc. = 0.0000e+00.
# Epoch. 570: loss = 5.9257e+04, acc = 0.0000e+00, valid. loss = 7.5835e+04, valid. acc. = 0.0000e+00.
# Epoch. 580: loss = 4.8427e+04, acc = 0.0000e+00, valid. loss = 1.8764e+04, valid. acc. = 0.0000e+00.
# Epoch. 590: loss = 1.8234e+04, acc = 0.0000e+00, valid. loss = 4.0667e+04, valid. acc. = 0.0000e+00.
# Epoch. 600: loss = 7.9033e+04, acc = 0.0000e+00, valid. loss = 9.6789e+03, valid. acc. = 0.0000e+00.
# Epoch. 610: loss = 7.9326e+04, acc = 0.0000e+00, valid. loss = 2.3625e+05, valid. acc. = 0.0000e+00.
# Epoch. 620: loss = 5.4949e+04, acc = 0.0000e+00, valid. loss = 1.3214e+05, valid. acc. = 0.0000e+00.
# Epoch. 630: loss = 2.7652e+04, acc = 0.0000e+00, valid. loss = 4.9525e+04, valid. acc. = 0.0000e+00.
# Epoch. 640: loss = 3.5436e+04, acc = 1.1123e-04, valid. loss = 1.7923e+04, valid. acc. = 1.1123e-04.
# Epoch. 650: loss = 8.6866e+04, acc = 0.0000e+00, valid. loss = 1.7499e+04, valid. acc. = 0.0000e+00.
# Epoch. 660: loss = 2.6496e+04, acc = 0.0000e+00, valid. loss = 3.8367e+04, valid. acc. = 0.0000e+00.
# Epoch. 670: loss = 2.2521e+04, acc = 0.0000e+00, valid. loss = 4.1927e+04, valid. acc. = 0.0000e+00.
# Epoch. 680: loss = 1.8583e+04, acc = 0.0000e+00, valid. loss = 3.7865e+04, valid. acc. = 0.0000e+00.
# Epoch. 690: loss = 2.7155e+04, acc = 0.0000e+00, valid. loss = 2.8625e+04, valid. acc. = 0.0000e+00.
# Epoch. 700: loss = 3.7378e+04, acc = 0.0000e+00, valid. loss = 6.3944e+04, valid. acc. = 0.0000e+00.
# Epoch. 710: loss = 2.4201e+04, acc = 0.0000e+00, valid. loss = 2.5033e+04, valid. acc. = 0.0000e+00.
# Epoch. 720: loss = 2.3835e+04, acc = 0.0000e+00, valid. loss = 5.0821e+04, valid. acc. = 0.0000e+00.
# Epoch. 730: loss = 2.9504e+04, acc = 0.0000e+00, valid. loss = 3.7663e+03, valid. acc. = 0.0000e+00.
# Epoch. 740: loss = 8.0550e+03, acc = 0.0000e+00, valid. loss = 1.2442e+04, valid. acc. = 0.0000e+00.
# Epoch. 750: loss = 2.8783e+04, acc = 0.0000e+00, valid. loss = 7.9748e+03, valid. acc. = 0.0000e+00.
# Epoch. 760: loss = 3.9536e+04, acc = 0.0000e+00, valid. loss = 1.4042e+04, valid. acc. = 0.0000e+00.
# Epoch. 770: loss = 3.5688e+03, acc = 0.0000e+00, valid. loss = 3.9532e+03, valid. acc. = 0.0000e+00.
# Epoch. 780: loss = 4.3384e+04, acc = 0.0000e+00, valid. loss = 8.1980e+03, valid. acc. = 0.0000e+00.
# Epoch. 790: loss = 6.4917e+04, acc = 0.0000e+00, valid. loss = 3.4486e+04, valid. acc. = 0.0000e+00.
# Epoch. 800: loss = 3.2263e+04, acc = 0.0000e+00, valid. loss = 4.8024e+04, valid. acc. = 0.0000e+00.
# Epoch. 810: loss = 1.5830e+04, acc = 0.0000e+00, valid. loss = 3.7775e+03, valid. acc. = 0.0000e+00.
# Epoch. 820: loss = 1.0475e+05, acc = 0.0000e+00, valid. loss = 6.1912e+04, valid. acc. = 0.0000e+00.
# Epoch. 830: loss = 6.4422e+04, acc = 0.0000e+00, valid. loss = 2.1884e+04, valid. acc. = 0.0000e+00.
# Epoch. 840: loss = 3.2659e+04, acc = 0.0000e+00, valid. loss = 3.7907e+04, valid. acc. = 0.0000e+00.
# Epoch. 850: loss = 1.2131e+04, acc = 0.0000e+00, valid. loss = 8.9091e+03, valid. acc. = 0.0000e+00.
# Epoch. 860: loss = 1.4582e+05, acc = 0.0000e+00, valid. loss = 2.2214e+04, valid. acc. = 0.0000e+00.
# Epoch. 870: loss = 2.9153e+04, acc = 0.0000e+00, valid. loss = 3.9394e+04, valid. acc. = 0.0000e+00.
# Epoch. 880: loss = 2.0052e+04, acc = 0.0000e+00, valid. loss = 4.9822e+03, valid. acc. = 0.0000e+00.
# Epoch. 890: loss = 1.8683e+04, acc = 0.0000e+00, valid. loss = 2.8596e+04, valid. acc. = 0.0000e+00.
# Epoch. 900: loss = 2.6252e+04, acc = 0.0000e+00, valid. loss = 1.7596e+04, valid. acc. = 0.0000e+00.
# Epoch. 910: loss = 3.3001e+04, acc = 0.0000e+00, valid. loss = 1.0987e+04, valid. acc. = 0.0000e+00.
# Epoch. 920: loss = 2.4838e+04, acc = 0.0000e+00, valid. loss = 5.8362e+04, valid. acc. = 0.0000e+00.
# Epoch. 930: loss = 2.8192e+03, acc = 0.0000e+00, valid. loss = 1.9812e+03, valid. acc. = 0.0000e+00.
# Epoch. 940: loss = 1.4845e+05, acc = 0.0000e+00, valid. loss = 1.0957e+05, valid. acc. = 0.0000e+00.
# Epoch. 950: loss = 1.8206e+04, acc = 0.0000e+00, valid. loss = 4.2856e+03, valid. acc. = 0.0000e+00.
# Epoch. 960: loss = 6.7449e+03, acc = 0.0000e+00, valid. loss = 1.0454e+04, valid. acc. = 0.0000e+00.
# KeyboardInterrupt

# %%
o = o.opt_Adam(0.001).compile()
o = o.optimize(10000000,10)
# Out:
# Epoch. 0: loss = 1.3169e+04, acc = 0.0000e+00, valid. loss = 5.3139e+03, valid. acc. = 0.0000e+00.
# Epoch. 10: loss = 2.2580e+03, acc = 0.0000e+00, valid. loss = 1.5942e+03, valid. acc. = 0.0000e+00.
# Epoch. 20: loss = 1.6064e+03, acc = 0.0000e+00, valid. loss = 1.4537e+03, valid. acc. = 0.0000e+00.
# Epoch. 30: loss = 1.3587e+03, acc = 0.0000e+00, valid. loss = 1.6240e+03, valid. acc. = 0.0000e+00.
# Epoch. 40: loss = 1.6730e+03, acc = 0.0000e+00, valid. loss = 1.2400e+03, valid. acc. = 0.0000e+00.
# Epoch. 50: loss = 1.4517e+03, acc = 0.0000e+00, valid. loss = 1.5582e+03, valid. acc. = 0.0000e+00.
# Epoch. 60: loss = 1.3897e+03, acc = 0.0000e+00, valid. loss = 1.6878e+03, valid. acc. = 0.0000e+00.
# Epoch. 70: loss = 1.1510e+03, acc = 0.0000e+00, valid. loss = 8.8843e+02, valid. acc. = 0.0000e+00.
# Epoch. 80: loss = 1.0825e+03, acc = 0.0000e+00, valid. loss = 9.4587e+02, valid. acc. = 0.0000e+00.
# Epoch. 90: loss = 1.3499e+03, acc = 0.0000e+00, valid. loss = 2.0312e+03, valid. acc. = 0.0000e+00.
# Epoch. 100: loss = 9.5352e+02, acc = 0.0000e+00, valid. loss = 7.8953e+02, valid. acc. = 0.0000e+00.
# Epoch. 110: loss = 1.0053e+03, acc = 0.0000e+00, valid. loss = 1.2234e+03, valid. acc. = 0.0000e+00.
# Epoch. 120: loss = 1.7306e+03, acc = 0.0000e+00, valid. loss = 2.1606e+03, valid. acc. = 0.0000e+00.
# Epoch. 130: loss = 1.2414e+03, acc = 0.0000e+00, valid. loss = 1.6322e+03, valid. acc. = 0.0000e+00.
# Epoch. 140: loss = 1.7626e+03, acc = 0.0000e+00, valid. loss = 1.4968e+03, valid. acc. = 0.0000e+00.
# Epoch. 150: loss = 1.0784e+03, acc = 0.0000e+00, valid. loss = 1.8401e+03, valid. acc. = 0.0000e+00.
# Epoch. 160: loss = 1.1426e+03, acc = 0.0000e+00, valid. loss = 1.9470e+03, valid. acc. = 0.0000e+00.
# Epoch. 170: loss = 1.4829e+03, acc = 0.0000e+00, valid. loss = 2.7704e+03, valid. acc. = 0.0000e+00.
# Epoch. 180: loss = 1.2273e+03, acc = 0.0000e+00, valid. loss = 1.1058e+03, valid. acc. = 0.0000e+00.
# Epoch. 190: loss = 9.8582e+02, acc = 0.0000e+00, valid. loss = 7.8662e+02, valid. acc. = 0.0000e+00.
# Epoch. 200: loss = 9.5878e+02, acc = 0.0000e+00, valid. loss = 8.4712e+02, valid. acc. = 0.0000e+00.
# Epoch. 210: loss = 1.4559e+03, acc = 0.0000e+00, valid. loss = 1.7237e+03, valid. acc. = 0.0000e+00.
# Epoch. 220: loss = 1.3853e+03, acc = 0.0000e+00, valid. loss = 8.7807e+02, valid. acc. = 0.0000e+00.
# Epoch. 230: loss = 9.1507e+02, acc = 0.0000e+00, valid. loss = 8.6481e+02, valid. acc. = 0.0000e+00.
# Epoch. 240: loss = 8.3887e+02, acc = 0.0000e+00, valid. loss = 8.8934e+02, valid. acc. = 0.0000e+00.
# Epoch. 250: loss = 7.9119e+02, acc = 0.0000e+00, valid. loss = 8.0660e+02, valid. acc. = 0.0000e+00.
# Epoch. 260: loss = 1.0766e+03, acc = 0.0000e+00, valid. loss = 1.0782e+03, valid. acc. = 0.0000e+00.
# Epoch. 270: loss = 1.2657e+03, acc = 0.0000e+00, valid. loss = 1.3671e+03, valid. acc. = 0.0000e+00.
# Epoch. 280: loss = 1.3883e+03, acc = 0.0000e+00, valid. loss = 1.6914e+03, valid. acc. = 0.0000e+00.
# Epoch. 290: loss = 1.4942e+03, acc = 0.0000e+00, valid. loss = 1.1677e+03, valid. acc. = 0.0000e+00.
# Epoch. 300: loss = 9.2661e+02, acc = 0.0000e+00, valid. loss = 1.2995e+03, valid. acc. = 0.0000e+00.
# Epoch. 310: loss = 1.2965e+03, acc = 0.0000e+00, valid. loss = 1.1872e+03, valid. acc. = 0.0000e+00.
# Epoch. 320: loss = 8.8026e+02, acc = 0.0000e+00, valid. loss = 9.8084e+02, valid. acc. = 0.0000e+00.
# KeyboardInterrupt

# %%
o = o.opt_Adam(0.0001).compile()
o = o.optimize(10000000,10)
# Out:
# Epoch. 0: loss = 7.4066e+02, acc = 0.0000e+00, valid. loss = 5.4975e+02, valid. acc. = 0.0000e+00.
# Epoch. 10: loss = 5.3114e+02, acc = 0.0000e+00, valid. loss = 5.2667e+02, valid. acc. = 0.0000e+00.
# Epoch. 20: loss = 5.2646e+02, acc = 0.0000e+00, valid. loss = 5.3838e+02, valid. acc. = 0.0000e+00.
# Epoch. 30: loss = 5.2169e+02, acc = 0.0000e+00, valid. loss = 5.2412e+02, valid. acc. = 0.0000e+00.
# Epoch. 40: loss = 5.1974e+02, acc = 0.0000e+00, valid. loss = 5.1799e+02, valid. acc. = 0.0000e+00.
# Epoch. 50: loss = 5.2103e+02, acc = 0.0000e+00, valid. loss = 5.1707e+02, valid. acc. = 0.0000e+00.
# Epoch. 60: loss = 5.1497e+02, acc = 0.0000e+00, valid. loss = 5.1308e+02, valid. acc. = 0.0000e+00.
# Epoch. 70: loss = 5.3506e+02, acc = 0.0000e+00, valid. loss = 5.1639e+02, valid. acc. = 0.0000e+00.
# Epoch. 80: loss = 5.1125e+02, acc = 0.0000e+00, valid. loss = 5.1784e+02, valid. acc. = 0.0000e+00.
# Epoch. 90: loss = 5.1153e+02, acc = 0.0000e+00, valid. loss = 5.1259e+02, valid. acc. = 0.0000e+00.
# Epoch. 100: loss = 5.1800e+02, acc = 0.0000e+00, valid. loss = 5.0846e+02, valid. acc. = 0.0000e+00.
# Epoch. 110: loss = 5.0491e+02, acc = 1.1123e-04, valid. loss = 5.0883e+02, valid. acc. = 1.1123e-04.
# Epoch. 120: loss = 5.0325e+02, acc = 1.1123e-04, valid. loss = 5.0311e+02, valid. acc. = 1.1123e-04.
# Epoch. 130: loss = 5.0433e+02, acc = 0.0000e+00, valid. loss = 5.0251e+02, valid. acc. = 0.0000e+00.
# Epoch. 140: loss = 5.0311e+02, acc = 0.0000e+00, valid. loss = 5.0798e+02, valid. acc. = 0.0000e+00.
# Epoch. 150: loss = 4.9931e+02, acc = 0.0000e+00, valid. loss = 4.9836e+02, valid. acc. = 0.0000e+00.
# Epoch. 160: loss = 5.1011e+02, acc = 0.0000e+00, valid. loss = 5.2908e+02, valid. acc. = 0.0000e+00.
# Epoch. 170: loss = 4.9690e+02, acc = 0.0000e+00, valid. loss = 4.9814e+02, valid. acc. = 0.0000e+00.
# Epoch. 180: loss = 4.9787e+02, acc = 0.0000e+00, valid. loss = 4.9675e+02, valid. acc. = 0.0000e+00.
# Epoch. 190: loss = 4.9337e+02, acc = 0.0000e+00, valid. loss = 4.9157e+02, valid. acc. = 0.0000e+00.
# Epoch. 200: loss = 5.0757e+02, acc = 0.0000e+00, valid. loss = 5.2781e+02, valid. acc. = 0.0000e+00.
# Epoch. 210: loss = 4.9242e+02, acc = 0.0000e+00, valid. loss = 4.8992e+02, valid. acc. = 0.0000e+00.
# Epoch. 220: loss = 4.9463e+02, acc = 1.1123e-04, valid. loss = 4.8910e+02, valid. acc. = 1.1123e-04.
# Epoch. 230: loss = 4.9707e+02, acc = 0.0000e+00, valid. loss = 5.0729e+02, valid. acc. = 0.0000e+00.
# Epoch. 240: loss = 4.9819e+02, acc = 0.0000e+00, valid. loss = 5.0145e+02, valid. acc. = 0.0000e+00.
# Epoch. 250: loss = 4.9129e+02, acc = 0.0000e+00, valid. loss = 4.8738e+02, valid. acc. = 0.0000e+00.
# Epoch. 260: loss = 4.8739e+02, acc = 0.0000e+00, valid. loss = 4.8880e+02, valid. acc. = 0.0000e+00.
# Epoch. 270: loss = 4.7924e+02, acc = 0.0000e+00, valid. loss = 4.9003e+02, valid. acc. = 0.0000e+00.
# Epoch. 280: loss = 4.8157e+02, acc = 0.0000e+00, valid. loss = 4.8320e+02, valid. acc. = 0.0000e+00.
# Epoch. 290: loss = 4.7602e+02, acc = 0.0000e+00, valid. loss = 4.7197e+02, valid. acc. = 0.0000e+00.
# Epoch. 300: loss = 4.7130e+02, acc = 0.0000e+00, valid. loss = 4.6873e+02, valid. acc. = 0.0000e+00.
# Epoch. 310: loss = 4.6955e+02, acc = 0.0000e+00, valid. loss = 4.6770e+02, valid. acc. = 0.0000e+00.
# Epoch. 320: loss = 4.6438e+02, acc = 0.0000e+00, valid. loss = 4.6586e+02, valid. acc. = 0.0000e+00.
# Epoch. 330: loss = 4.7571e+02, acc = 0.0000e+00, valid. loss = 4.6601e+02, valid. acc. = 0.0000e+00.
# Epoch. 340: loss = 4.6582e+02, acc = 0.0000e+00, valid. loss = 4.7057e+02, valid. acc. = 0.0000e+00.
# Epoch. 350: loss = 4.6780e+02, acc = 0.0000e+00, valid. loss = 4.6280e+02, valid. acc. = 0.0000e+00.
# Epoch. 360: loss = 4.6460e+02, acc = 0.0000e+00, valid. loss = 4.6235e+02, valid. acc. = 0.0000e+00.
# Epoch. 370: loss = 4.6638e+02, acc = 0.0000e+00, valid. loss = 4.6412e+02, valid. acc. = 0.0000e+00.
# Epoch. 380: loss = 4.6055e+02, acc = 0.0000e+00, valid. loss = 4.6086e+02, valid. acc. = 0.0000e+00.
# Epoch. 390: loss = 4.6167e+02, acc = 0.0000e+00, valid. loss = 4.6424e+02, valid. acc. = 0.0000e+00.
# Epoch. 400: loss = 4.7168e+02, acc = 0.0000e+00, valid. loss = 4.5780e+02, valid. acc. = 0.0000e+00.
# Epoch. 410: loss = 4.6191e+02, acc = 0.0000e+00, valid. loss = 4.5990e+02, valid. acc. = 0.0000e+00.
# Epoch. 420: loss = 4.6779e+02, acc = 0.0000e+00, valid. loss = 4.6113e+02, valid. acc. = 0.0000e+00.
# Epoch. 430: loss = 4.5684e+02, acc = 0.0000e+00, valid. loss = 4.5752e+02, valid. acc. = 0.0000e+00.
# Epoch. 440: loss = 4.6267e+02, acc = 0.0000e+00, valid. loss = 4.6462e+02, valid. acc. = 0.0000e+00.
# Epoch. 450: loss = 4.6392e+02, acc = 0.0000e+00, valid. loss = 4.8278e+02, valid. acc. = 0.0000e+00.
# Epoch. 460: loss = 4.5194e+02, acc = 0.0000e+00, valid. loss = 4.5737e+02, valid. acc. = 0.0000e+00.
# Epoch. 470: loss = 4.5496e+02, acc = 0.0000e+00, valid. loss = 4.5952e+02, valid. acc. = 0.0000e+00.
# Epoch. 480: loss = 4.6235e+02, acc = 0.0000e+00, valid. loss = 4.7015e+02, valid. acc. = 0.0000e+00.
# Epoch. 490: loss = 4.5271e+02, acc = 0.0000e+00, valid. loss = 4.5764e+02, valid. acc. = 0.0000e+00.
# Epoch. 500: loss = 4.5284e+02, acc = 1.1123e-04, valid. loss = 4.5115e+02, valid. acc. = 1.1123e-04.
# Epoch. 510: loss = 4.5145e+02, acc = 0.0000e+00, valid. loss = 4.5027e+02, valid. acc. = 0.0000e+00.
# Epoch. 520: loss = 4.4940e+02, acc = 0.0000e+00, valid. loss = 4.5464e+02, valid. acc. = 0.0000e+00.
# Epoch. 530: loss = 4.5494e+02, acc = 0.0000e+00, valid. loss = 4.5579e+02, valid. acc. = 0.0000e+00.
# Epoch. 540: loss = 4.5303e+02, acc = 0.0000e+00, valid. loss = 4.4780e+02, valid. acc. = 0.0000e+00.
# Epoch. 550: loss = 4.4794e+02, acc = 0.0000e+00, valid. loss = 4.4804e+02, valid. acc. = 0.0000e+00.
# Epoch. 560: loss = 4.4906e+02, acc = 0.0000e+00, valid. loss = 4.4866e+02, valid. acc. = 0.0000e+00.
# Epoch. 570: loss = 4.5400e+02, acc = 0.0000e+00, valid. loss = 4.5962e+02, valid. acc. = 0.0000e+00.
# Epoch. 580: loss = 4.4651e+02, acc = 1.1123e-04, valid. loss = 4.4856e+02, valid. acc. = 1.1123e-04.
# Epoch. 590: loss = 4.5138e+02, acc = 0.0000e+00, valid. loss = 4.5969e+02, valid. acc. = 0.0000e+00.
# Epoch. 600: loss = 4.4498e+02, acc = 0.0000e+00, valid. loss = 4.4864e+02, valid. acc. = 0.0000e+00.
# Epoch. 610: loss = 4.5338e+02, acc = 0.0000e+00, valid. loss = 4.4666e+02, valid. acc. = 0.0000e+00.
# Epoch. 620: loss = 4.5165e+02, acc = 0.0000e+00, valid. loss = 4.5813e+02, valid. acc. = 0.0000e+00.
# Epoch. 630: loss = 4.4880e+02, acc = 0.0000e+00, valid. loss = 4.5048e+02, valid. acc. = 0.0000e+00.
# Epoch. 640: loss = 4.4547e+02, acc = 1.1123e-04, valid. loss = 4.4809e+02, valid. acc. = 1.1123e-04.
# Epoch. 650: loss = 4.4846e+02, acc = 0.0000e+00, valid. loss = 4.4696e+02, valid. acc. = 0.0000e+00.
# Epoch. 660: loss = 4.4561e+02, acc = 0.0000e+00, valid. loss = 4.4728e+02, valid. acc. = 0.0000e+00.
# Epoch. 670: loss = 4.4668e+02, acc = 0.0000e+00, valid. loss = 4.5480e+02, valid. acc. = 0.0000e+00.
# Epoch. 680: loss = 4.4680e+02, acc = 0.0000e+00, valid. loss = 4.4579e+02, valid. acc. = 0.0000e+00.
# Epoch. 690: loss = 4.4841e+02, acc = 0.0000e+00, valid. loss = 4.4904e+02, valid. acc. = 0.0000e+00.
# Epoch. 700: loss = 4.4771e+02, acc = 0.0000e+00, valid. loss = 4.4423e+02, valid. acc. = 0.0000e+00.
# Epoch. 710: loss = 4.4856e+02, acc = 0.0000e+00, valid. loss = 4.4456e+02, valid. acc. = 0.0000e+00.
# Epoch. 720: loss = 4.4818e+02, acc = 0.0000e+00, valid. loss = 4.5145e+02, valid. acc. = 0.0000e+00.
# Epoch. 730: loss = 4.4418e+02, acc = 0.0000e+00, valid. loss = 4.4240e+02, valid. acc. = 0.0000e+00.
# Epoch. 740: loss = 4.4292e+02, acc = 1.1123e-04, valid. loss = 4.4182e+02, valid. acc. = 1.1123e-04.
# Epoch. 750: loss = 4.4653e+02, acc = 1.1123e-04, valid. loss = 4.4406e+02, valid. acc. = 1.1123e-04.
# Epoch. 760: loss = 4.4542e+02, acc = 0.0000e+00, valid. loss = 4.4131e+02, valid. acc. = 0.0000e+00.
# Epoch. 770: loss = 4.4529e+02, acc = 0.0000e+00, valid. loss = 4.4332e+02, valid. acc. = 0.0000e+00.
# Epoch. 780: loss = 4.4499e+02, acc = 1.1123e-04, valid. loss = 4.4248e+02, valid. acc. = 1.1123e-04.
# Epoch. 790: loss = 4.4997e+02, acc = 0.0000e+00, valid. loss = 4.4082e+02, valid. acc. = 0.0000e+00.
# Epoch. 800: loss = 4.4412e+02, acc = 0.0000e+00, valid. loss = 4.4203e+02, valid. acc. = 0.0000e+00.
# Epoch. 810: loss = 4.4695e+02, acc = 0.0000e+00, valid. loss = 4.4505e+02, valid. acc. = 0.0000e+00.
# Epoch. 820: loss = 4.4891e+02, acc = 0.0000e+00, valid. loss = 4.5204e+02, valid. acc. = 0.0000e+00.
# Epoch. 830: loss = 4.4048e+02, acc = 0.0000e+00, valid. loss = 4.4213e+02, valid. acc. = 0.0000e+00.
# Epoch. 840: loss = 4.4665e+02, acc = 0.0000e+00, valid. loss = 4.4090e+02, valid. acc. = 0.0000e+00.
# Epoch. 850: loss = 4.4108e+02, acc = 0.0000e+00, valid. loss = 4.4302e+02, valid. acc. = 0.0000e+00.
# Epoch. 860: loss = 4.5029e+02, acc = 0.0000e+00, valid. loss = 4.6662e+02, valid. acc. = 0.0000e+00.
# Epoch. 870: loss = 4.4114e+02, acc = 0.0000e+00, valid. loss = 4.4034e+02, valid. acc. = 0.0000e+00.
# Epoch. 880: loss = 4.4396e+02, acc = 0.0000e+00, valid. loss = 4.4539e+02, valid. acc. = 0.0000e+00.
# Epoch. 890: loss = 4.4414e+02, acc = 0.0000e+00, valid. loss = 4.3863e+02, valid. acc. = 0.0000e+00.
# Epoch. 900: loss = 4.4189e+02, acc = 0.0000e+00, valid. loss = 4.4324e+02, valid. acc. = 0.0000e+00.
# Epoch. 910: loss = 4.4592e+02, acc = 0.0000e+00, valid. loss = 4.4508e+02, valid. acc. = 0.0000e+00.
# Epoch. 920: loss = 4.4315e+02, acc = 0.0000e+00, valid. loss = 4.5363e+02, valid. acc. = 0.0000e+00.
# Epoch. 930: loss = 4.4347e+02, acc = 0.0000e+00, valid. loss = 4.4160e+02, valid. acc. = 0.0000e+00.
# Epoch. 940: loss = 4.4069e+02, acc = 1.1123e-04, valid. loss = 4.3966e+02, valid. acc. = 1.1123e-04.
# Epoch. 950: loss = 4.4372e+02, acc = 0.0000e+00, valid. loss = 4.3870e+02, valid. acc. = 0.0000e+00.
# Epoch. 960: loss = 4.4266e+02, acc = 0.0000e+00, valid. loss = 4.3699e+02, valid. acc. = 0.0000e+00.
# Epoch. 970: loss = 4.5041e+02, acc = 0.0000e+00, valid. loss = 4.4891e+02, valid. acc. = 0.0000e+00.
# Epoch. 980: loss = 4.4149e+02, acc = 0.0000e+00, valid. loss = 4.4945e+02, valid. acc. = 0.0000e+00.
# Epoch. 990: loss = 4.3530e+02, acc = 0.0000e+00, valid. loss = 4.4185e+02, valid. acc. = 0.0000e+00.
# Epoch. 1000: loss = 4.4301e+02, acc = 0.0000e+00, valid. loss = 4.3854e+02, valid. acc. = 0.0000e+00.
# Epoch. 1010: loss = 4.3444e+02, acc = 0.0000e+00, valid. loss = 4.4047e+02, valid. acc. = 0.0000e+00.
# Epoch. 1020: loss = 4.4189e+02, acc = 0.0000e+00, valid. loss = 4.3829e+02, valid. acc. = 0.0000e+00.
# Epoch. 1030: loss = 4.3931e+02, acc = 0.0000e+00, valid. loss = 4.3680e+02, valid. acc. = 0.0000e+00.
# Epoch. 1040: loss = 4.4050e+02, acc = 0.0000e+00, valid. loss = 4.3574e+02, valid. acc. = 0.0000e+00.
# Epoch. 1050: loss = 4.3746e+02, acc = 0.0000e+00, valid. loss = 4.3726e+02, valid. acc. = 0.0000e+00.
# Epoch. 1060: loss = 4.4308e+02, acc = 0.0000e+00, valid. loss = 4.5036e+02, valid. acc. = 0.0000e+00.
# Epoch. 1070: loss = 4.3724e+02, acc = 0.0000e+00, valid. loss = 4.3671e+02, valid. acc. = 0.0000e+00.
# Epoch. 1080: loss = 4.4352e+02, acc = 0.0000e+00, valid. loss = 4.4145e+02, valid. acc. = 0.0000e+00.
# Epoch. 1090: loss = 4.4128e+02, acc = 0.0000e+00, valid. loss = 4.3607e+02, valid. acc. = 0.0000e+00.
# Epoch. 1100: loss = 4.4198e+02, acc = 0.0000e+00, valid. loss = 4.3578e+02, valid. acc. = 0.0000e+00.
# Epoch. 1110: loss = 4.3769e+02, acc = 0.0000e+00, valid. loss = 4.3410e+02, valid. acc. = 0.0000e+00.
# Epoch. 1120: loss = 4.3657e+02, acc = 0.0000e+00, valid. loss = 4.3611e+02, valid. acc. = 0.0000e+00.
# Epoch. 1130: loss = 4.3773e+02, acc = 0.0000e+00, valid. loss = 4.3453e+02, valid. acc. = 0.0000e+00.
# Epoch. 1140: loss = 4.3386e+02, acc = 0.0000e+00, valid. loss = 4.3335e+02, valid. acc. = 0.0000e+00.
# Epoch. 1150: loss = 4.4252e+02, acc = 0.0000e+00, valid. loss = 4.3971e+02, valid. acc. = 0.0000e+00.
# Epoch. 1160: loss = 4.4222e+02, acc = 0.0000e+00, valid. loss = 4.3331e+02, valid. acc. = 0.0000e+00.
# Epoch. 1170: loss = 4.3743e+02, acc = 0.0000e+00, valid. loss = 4.3349e+02, valid. acc. = 0.0000e+00.
# Epoch. 1180: loss = 4.3770e+02, acc = 0.0000e+00, valid. loss = 4.3392e+02, valid. acc. = 0.0000e+00.
# Epoch. 1190: loss = 4.3561e+02, acc = 0.0000e+00, valid. loss = 4.3347e+02, valid. acc. = 0.0000e+00.
# Epoch. 1200: loss = 4.3278e+02, acc = 1.1123e-04, valid. loss = 4.3728e+02, valid. acc. = 1.1123e-04.
# Epoch. 1210: loss = 4.4481e+02, acc = 0.0000e+00, valid. loss = 4.4002e+02, valid. acc. = 0.0000e+00.
# Epoch. 1220: loss = 4.3202e+02, acc = 0.0000e+00, valid. loss = 4.3260e+02, valid. acc. = 0.0000e+00.
# Epoch. 1230: loss = 4.3163e+02, acc = 0.0000e+00, valid. loss = 4.3810e+02, valid. acc. = 0.0000e+00.
# Epoch. 1240: loss = 4.3942e+02, acc = 0.0000e+00, valid. loss = 4.3508e+02, valid. acc. = 0.0000e+00.
# Epoch. 1250: loss = 4.3760e+02, acc = 0.0000e+00, valid. loss = 4.3514e+02, valid. acc. = 0.0000e+00.
# Epoch. 1260: loss = 4.3103e+02, acc = 0.0000e+00, valid. loss = 4.3289e+02, valid. acc. = 0.0000e+00.
# Epoch. 1270: loss = 4.3130e+02, acc = 0.0000e+00, valid. loss = 4.3239e+02, valid. acc. = 0.0000e+00.
# Epoch. 1280: loss = 4.3270e+02, acc = 0.0000e+00, valid. loss = 4.3145e+02, valid. acc. = 0.0000e+00.
# Epoch. 1290: loss = 4.2882e+02, acc = 0.0000e+00, valid. loss = 4.3190e+02, valid. acc. = 0.0000e+00.
# Epoch. 1300: loss = 4.3493e+02, acc = 0.0000e+00, valid. loss = 4.3377e+02, valid. acc. = 0.0000e+00.
# Epoch. 1310: loss = 4.3456e+02, acc = 0.0000e+00, valid. loss = 4.3819e+02, valid. acc. = 0.0000e+00.
# Epoch. 1320: loss = 4.2799e+02, acc = 0.0000e+00, valid. loss = 4.3586e+02, valid. acc. = 0.0000e+00.
# Epoch. 1330: loss = 4.3625e+02, acc = 0.0000e+00, valid. loss = 4.4601e+02, valid. acc. = 0.0000e+00.
# Epoch. 1340: loss = 4.3615e+02, acc = 0.0000e+00, valid. loss = 4.2970e+02, valid. acc. = 0.0000e+00.
# Epoch. 1350: loss = 4.4052e+02, acc = 1.1123e-04, valid. loss = 4.3168e+02, valid. acc. = 1.1123e-04.
# Epoch. 1360: loss = 4.3734e+02, acc = 0.0000e+00, valid. loss = 4.3477e+02, valid. acc. = 0.0000e+00.
# Epoch. 1370: loss = 4.3613e+02, acc = 0.0000e+00, valid. loss = 4.3823e+02, valid. acc. = 0.0000e+00.
# Epoch. 1380: loss = 4.3337e+02, acc = 0.0000e+00, valid. loss = 4.3053e+02, valid. acc. = 0.0000e+00.
# Epoch. 1390: loss = 4.2883e+02, acc = 0.0000e+00, valid. loss = 4.3163e+02, valid. acc. = 0.0000e+00.
# Epoch. 1400: loss = 4.2896e+02, acc = 0.0000e+00, valid. loss = 4.2846e+02, valid. acc. = 0.0000e+00.
# Epoch. 1410: loss = 4.4147e+02, acc = 0.0000e+00, valid. loss = 4.5081e+02, valid. acc. = 0.0000e+00.
# Epoch. 1420: loss = 4.3364e+02, acc = 0.0000e+00, valid. loss = 4.4304e+02, valid. acc. = 0.0000e+00.
# Epoch. 1430: loss = 4.3217e+02, acc = 0.0000e+00, valid. loss = 4.3679e+02, valid. acc. = 0.0000e+00.
# Epoch. 1440: loss = 4.4613e+02, acc = 0.0000e+00, valid. loss = 4.4696e+02, valid. acc. = 0.0000e+00.
# Epoch. 1450: loss = 4.3004e+02, acc = 0.0000e+00, valid. loss = 4.3155e+02, valid. acc. = 0.0000e+00.
# Epoch. 1460: loss = 4.4144e+02, acc = 0.0000e+00, valid. loss = 4.3872e+02, valid. acc. = 0.0000e+00.
# Epoch. 1470: loss = 4.2779e+02, acc = 0.0000e+00, valid. loss = 4.2741e+02, valid. acc. = 0.0000e+00.
# Epoch. 1480: loss = 4.2796e+02, acc = 2.2247e-04, valid. loss = 4.2988e+02, valid. acc. = 2.2247e-04.
# Epoch. 1490: loss = 4.2838e+02, acc = 0.0000e+00, valid. loss = 4.2722e+02, valid. acc. = 0.0000e+00.
# Epoch. 1500: loss = 4.2721e+02, acc = 0.0000e+00, valid. loss = 4.3166e+02, valid. acc. = 0.0000e+00.
# Epoch. 1510: loss = 4.3616e+02, acc = 0.0000e+00, valid. loss = 4.3338e+02, valid. acc. = 0.0000e+00.
# Epoch. 1520: loss = 4.2642e+02, acc = 0.0000e+00, valid. loss = 4.2749e+02, valid. acc. = 0.0000e+00.
# Epoch. 1530: loss = 4.2740e+02, acc = 0.0000e+00, valid. loss = 4.3194e+02, valid. acc. = 0.0000e+00.
# Epoch. 1540: loss = 4.3727e+02, acc = 0.0000e+00, valid. loss = 4.3511e+02, valid. acc. = 0.0000e+00.
# Epoch. 1550: loss = 4.3209e+02, acc = 0.0000e+00, valid. loss = 4.2940e+02, valid. acc. = 0.0000e+00.
# Epoch. 1560: loss = 4.3095e+02, acc = 0.0000e+00, valid. loss = 4.3173e+02, valid. acc. = 0.0000e+00.
# Epoch. 1570: loss = 4.2880e+02, acc = 0.0000e+00, valid. loss = 4.2980e+02, valid. acc. = 0.0000e+00.
# Epoch. 1580: loss = 4.3219e+02, acc = 0.0000e+00, valid. loss = 4.2505e+02, valid. acc. = 0.0000e+00.
# Epoch. 1590: loss = 4.2896e+02, acc = 0.0000e+00, valid. loss = 4.2523e+02, valid. acc. = 0.0000e+00.
# Epoch. 1600: loss = 4.2961e+02, acc = 0.0000e+00, valid. loss = 4.2780e+02, valid. acc. = 0.0000e+00.
# Epoch. 1610: loss = 4.2777e+02, acc = 0.0000e+00, valid. loss = 4.2549e+02, valid. acc. = 0.0000e+00.
# Epoch. 1620: loss = 4.2995e+02, acc = 1.1123e-04, valid. loss = 4.2541e+02, valid. acc. = 1.1123e-04.
# Epoch. 1630: loss = 4.2760e+02, acc = 1.1123e-04, valid. loss = 4.2513e+02, valid. acc. = 1.1123e-04.
# Epoch. 1640: loss = 4.3010e+02, acc = 0.0000e+00, valid. loss = 4.2793e+02, valid. acc. = 0.0000e+00.
# Epoch. 1650: loss = 4.3007e+02, acc = 0.0000e+00, valid. loss = 4.2733e+02, valid. acc. = 0.0000e+00.
# Epoch. 1660: loss = 4.3109e+02, acc = 0.0000e+00, valid. loss = 4.3006e+02, valid. acc. = 0.0000e+00.
# Epoch. 1670: loss = 4.2421e+02, acc = 1.1123e-04, valid. loss = 4.2549e+02, valid. acc. = 1.1123e-04.
# Epoch. 1680: loss = 4.2728e+02, acc = 1.1123e-04, valid. loss = 4.2819e+02, valid. acc. = 1.1123e-04.
# Epoch. 1690: loss = 4.2911e+02, acc = 1.1123e-04, valid. loss = 4.2367e+02, valid. acc. = 1.1123e-04.
# Epoch. 1700: loss = 4.2591e+02, acc = 0.0000e+00, valid. loss = 4.2466e+02, valid. acc. = 0.0000e+00.
# Epoch. 1710: loss = 4.3380e+02, acc = 0.0000e+00, valid. loss = 4.2531e+02, valid. acc. = 0.0000e+00.
# Epoch. 1720: loss = 4.3458e+02, acc = 1.1123e-04, valid. loss = 4.3969e+02, valid. acc. = 1.1123e-04.
# Epoch. 1730: loss = 4.3837e+02, acc = 0.0000e+00, valid. loss = 4.3460e+02, valid. acc. = 0.0000e+00.
# Epoch. 1740: loss = 4.2643e+02, acc = 0.0000e+00, valid. loss = 4.2257e+02, valid. acc. = 0.0000e+00.
# Epoch. 1750: loss = 4.2991e+02, acc = 0.0000e+00, valid. loss = 4.3023e+02, valid. acc. = 0.0000e+00.
# Epoch. 1760: loss = 4.2392e+02, acc = 0.0000e+00, valid. loss = 4.2130e+02, valid. acc. = 0.0000e+00.
# Epoch. 1770: loss = 4.2146e+02, acc = 1.1123e-04, valid. loss = 4.2453e+02, valid. acc. = 1.1123e-04.
# Epoch. 1780: loss = 4.2722e+02, acc = 0.0000e+00, valid. loss = 4.2123e+02, valid. acc. = 0.0000e+00.
# Epoch. 1790: loss = 4.2320e+02, acc = 0.0000e+00, valid. loss = 4.2147e+02, valid. acc. = 0.0000e+00.
# Epoch. 1800: loss = 4.3009e+02, acc = 0.0000e+00, valid. loss = 4.3200e+02, valid. acc. = 0.0000e+00.
# Epoch. 1810: loss = 4.1963e+02, acc = 0.0000e+00, valid. loss = 4.2082e+02, valid. acc. = 0.0000e+00.
# Epoch. 1820: loss = 4.2650e+02, acc = 0.0000e+00, valid. loss = 4.2458e+02, valid. acc. = 0.0000e+00.
# Epoch. 1830: loss = 4.2418e+02, acc = 1.1123e-04, valid. loss = 4.2039e+02, valid. acc. = 1.1123e-04.
# Epoch. 1840: loss = 4.2195e+02, acc = 0.0000e+00, valid. loss = 4.2363e+02, valid. acc. = 0.0000e+00.
# Epoch. 1850: loss = 4.2517e+02, acc = 0.0000e+00, valid. loss = 4.2160e+02, valid. acc. = 0.0000e+00.
# Epoch. 1860: loss = 4.1784e+02, acc = 0.0000e+00, valid. loss = 4.1773e+02, valid. acc. = 0.0000e+00.
# Epoch. 1870: loss = 4.2268e+02, acc = 0.0000e+00, valid. loss = 4.2083e+02, valid. acc. = 0.0000e+00.
# Epoch. 1880: loss = 4.2112e+02, acc = 0.0000e+00, valid. loss = 4.2833e+02, valid. acc. = 0.0000e+00.
# Epoch. 1890: loss = 4.1876e+02, acc = 0.0000e+00, valid. loss = 4.1710e+02, valid. acc. = 0.0000e+00.
# Epoch. 1900: loss = 4.1877e+02, acc = 0.0000e+00, valid. loss = 4.1549e+02, valid. acc. = 0.0000e+00.
# Epoch. 1910: loss = 4.2068e+02, acc = 0.0000e+00, valid. loss = 4.1578e+02, valid. acc. = 0.0000e+00.
# Epoch. 1920: loss = 4.1730e+02, acc = 0.0000e+00, valid. loss = 4.1456e+02, valid. acc. = 0.0000e+00.
# Epoch. 1930: loss = 4.1855e+02, acc = 0.0000e+00, valid. loss = 4.1683e+02, valid. acc. = 0.0000e+00.
# Epoch. 1940: loss = 4.1843e+02, acc = 0.0000e+00, valid. loss = 4.2325e+02, valid. acc. = 0.0000e+00.
# Epoch. 1950: loss = 4.1791e+02, acc = 0.0000e+00, valid. loss = 4.2043e+02, valid. acc. = 0.0000e+00.
# Epoch. 1960: loss = 4.2434e+02, acc = 0.0000e+00, valid. loss = 4.2087e+02, valid. acc. = 0.0000e+00.
# Epoch. 1970: loss = 4.1581e+02, acc = 0.0000e+00, valid. loss = 4.1861e+02, valid. acc. = 0.0000e+00.
# Epoch. 1980: loss = 4.1977e+02, acc = 0.0000e+00, valid. loss = 4.1308e+02, valid. acc. = 0.0000e+00.
# Epoch. 1990: loss = 4.1578e+02, acc = 0.0000e+00, valid. loss = 4.1385e+02, valid. acc. = 0.0000e+00.
# Epoch. 2000: loss = 4.1983e+02, acc = 0.0000e+00, valid. loss = 4.1841e+02, valid. acc. = 0.0000e+00.
# Epoch. 2010: loss = 4.1095e+02, acc = 0.0000e+00, valid. loss = 4.1226e+02, valid. acc. = 0.0000e+00.
# Epoch. 2020: loss = 4.2084e+02, acc = 0.0000e+00, valid. loss = 4.1585e+02, valid. acc. = 0.0000e+00.
# Epoch. 2030: loss = 4.2214e+02, acc = 1.1123e-04, valid. loss = 4.1469e+02, valid. acc. = 1.1123e-04.
# Epoch. 2040: loss = 4.2068e+02, acc = 1.1123e-04, valid. loss = 4.2015e+02, valid. acc. = 1.1123e-04.
# Epoch. 2050: loss = 4.2489e+02, acc = 0.0000e+00, valid. loss = 4.1351e+02, valid. acc. = 0.0000e+00.
# Epoch. 2060: loss = 4.1774e+02, acc = 0.0000e+00, valid. loss = 4.1277e+02, valid. acc. = 0.0000e+00.
# Epoch. 2070: loss = 4.2934e+02, acc = 0.0000e+00, valid. loss = 4.3134e+02, valid. acc. = 0.0000e+00.
# Epoch. 2080: loss = 4.1444e+02, acc = 0.0000e+00, valid. loss = 4.1174e+02, valid. acc. = 0.0000e+00.
# Epoch. 2090: loss = 4.1744e+02, acc = 0.0000e+00, valid. loss = 4.1172e+02, valid. acc. = 0.0000e+00.
# Epoch. 2100: loss = 4.1059e+02, acc = 0.0000e+00, valid. loss = 4.1699e+02, valid. acc. = 0.0000e+00.
# Epoch. 2110: loss = 4.1360e+02, acc = 0.0000e+00, valid. loss = 4.1353e+02, valid. acc. = 0.0000e+00.
# Epoch. 2120: loss = 4.1487e+02, acc = 0.0000e+00, valid. loss = 4.1833e+02, valid. acc. = 0.0000e+00.
# Epoch. 2130: loss = 4.1503e+02, acc = 0.0000e+00, valid. loss = 4.1070e+02, valid. acc. = 0.0000e+00.
# Epoch. 2140: loss = 4.1313e+02, acc = 0.0000e+00, valid. loss = 4.0876e+02, valid. acc. = 0.0000e+00.
# Epoch. 2150: loss = 4.0915e+02, acc = 0.0000e+00, valid. loss = 4.0883e+02, valid. acc. = 0.0000e+00.
# Epoch. 2160: loss = 4.1171e+02, acc = 0.0000e+00, valid. loss = 4.0865e+02, valid. acc. = 0.0000e+00.
# Epoch. 2170: loss = 4.1333e+02, acc = 0.0000e+00, valid. loss = 4.0808e+02, valid. acc. = 0.0000e+00.
# Epoch. 2180: loss = 4.1094e+02, acc = 0.0000e+00, valid. loss = 4.0727e+02, valid. acc. = 0.0000e+00.
# Epoch. 2190: loss = 4.0989e+02, acc = 0.0000e+00, valid. loss = 4.0910e+02, valid. acc. = 0.0000e+00.
# Epoch. 2200: loss = 4.1736e+02, acc = 0.0000e+00, valid. loss = 4.2150e+02, valid. acc. = 0.0000e+00.
# Epoch. 2210: loss = 4.0988e+02, acc = 0.0000e+00, valid. loss = 4.1410e+02, valid. acc. = 0.0000e+00.
# Epoch. 2220: loss = 4.2364e+02, acc = 0.0000e+00, valid. loss = 4.3772e+02, valid. acc. = 0.0000e+00.
# Epoch. 2230: loss = 4.1646e+02, acc = 0.0000e+00, valid. loss = 4.3364e+02, valid. acc. = 0.0000e+00.
# Epoch. 2240: loss = 4.1012e+02, acc = 1.1123e-04, valid. loss = 4.0698e+02, valid. acc. = 1.1123e-04.
# Epoch. 2250: loss = 4.0801e+02, acc = 1.1123e-04, valid. loss = 4.0714e+02, valid. acc. = 1.1123e-04.
# Epoch. 2260: loss = 4.1612e+02, acc = 0.0000e+00, valid. loss = 4.1437e+02, valid. acc. = 0.0000e+00.
# Epoch. 2270: loss = 4.1006e+02, acc = 0.0000e+00, valid. loss = 4.0641e+02, valid. acc. = 0.0000e+00.
# Epoch. 2280: loss = 4.0945e+02, acc = 0.0000e+00, valid. loss = 4.0897e+02, valid. acc. = 0.0000e+00.
# Epoch. 2290: loss = 4.0771e+02, acc = 0.0000e+00, valid. loss = 4.0532e+02, valid. acc. = 0.0000e+00.
# Epoch. 2300: loss = 4.0926e+02, acc = 0.0000e+00, valid. loss = 4.1164e+02, valid. acc. = 0.0000e+00.
# Epoch. 2310: loss = 4.0681e+02, acc = 0.0000e+00, valid. loss = 4.0465e+02, valid. acc. = 0.0000e+00.
# Epoch. 2320: loss = 4.1100e+02, acc = 1.1123e-04, valid. loss = 4.1875e+02, valid. acc. = 1.1123e-04.
# Epoch. 2330: loss = 4.0991e+02, acc = 0.0000e+00, valid. loss = 4.0596e+02, valid. acc. = 0.0000e+00.
# Epoch. 2340: loss = 4.0595e+02, acc = 0.0000e+00, valid. loss = 4.0571e+02, valid. acc. = 0.0000e+00.
# Epoch. 2350: loss = 4.0690e+02, acc = 0.0000e+00, valid. loss = 4.0431e+02, valid. acc. = 0.0000e+00.
# Epoch. 2360: loss = 4.0742e+02, acc = 1.1123e-04, valid. loss = 4.0422e+02, valid. acc. = 1.1123e-04.
# Epoch. 2370: loss = 4.1263e+02, acc = 0.0000e+00, valid. loss = 4.1322e+02, valid. acc. = 0.0000e+00.
# Epoch. 2380: loss = 4.1834e+02, acc = 0.0000e+00, valid. loss = 4.2440e+02, valid. acc. = 0.0000e+00.
# Epoch. 2390: loss = 4.0578e+02, acc = 1.1123e-04, valid. loss = 4.0432e+02, valid. acc. = 1.1123e-04.
# Epoch. 2400: loss = 4.0319e+02, acc = 0.0000e+00, valid. loss = 4.0434e+02, valid. acc. = 0.0000e+00.
# Epoch. 2410: loss = 4.0799e+02, acc = 1.1123e-04, valid. loss = 4.0346e+02, valid. acc. = 1.1123e-04.
# Epoch. 2420: loss = 4.1026e+02, acc = 0.0000e+00, valid. loss = 4.1149e+02, valid. acc. = 0.0000e+00.
# Epoch. 2430: loss = 4.0889e+02, acc = 0.0000e+00, valid. loss = 4.0473e+02, valid. acc. = 0.0000e+00.
# Epoch. 2440: loss = 4.0415e+02, acc = 0.0000e+00, valid. loss = 4.0398e+02, valid. acc. = 0.0000e+00.
# Epoch. 2450: loss = 4.0811e+02, acc = 0.0000e+00, valid. loss = 4.0342e+02, valid. acc. = 0.0000e+00.
# Epoch. 2460: loss = 4.0496e+02, acc = 0.0000e+00, valid. loss = 4.0345e+02, valid. acc. = 0.0000e+00.
# Epoch. 2470: loss = 4.0088e+02, acc = 0.0000e+00, valid. loss = 4.0665e+02, valid. acc. = 0.0000e+00.
# Epoch. 2480: loss = 4.0486e+02, acc = 1.1123e-04, valid. loss = 4.0674e+02, valid. acc. = 1.1123e-04.
# Epoch. 2490: loss = 4.0577e+02, acc = 0.0000e+00, valid. loss = 4.0939e+02, valid. acc. = 0.0000e+00.
# Epoch. 2500: loss = 4.1412e+02, acc = 0.0000e+00, valid. loss = 4.0668e+02, valid. acc. = 0.0000e+00.
# Epoch. 2510: loss = 4.0340e+02, acc = 0.0000e+00, valid. loss = 4.0216e+02, valid. acc. = 0.0000e+00.
# Epoch. 2520: loss = 4.0646e+02, acc = 1.1123e-04, valid. loss = 4.0270e+02, valid. acc. = 1.1123e-04.
# Epoch. 2530: loss = 4.0561e+02, acc = 0.0000e+00, valid. loss = 4.0352e+02, valid. acc. = 0.0000e+00.
# Epoch. 2540: loss = 4.0345e+02, acc = 0.0000e+00, valid. loss = 4.1253e+02, valid. acc. = 0.0000e+00.
# Epoch. 2550: loss = 4.0322e+02, acc = 0.0000e+00, valid. loss = 4.0214e+02, valid. acc. = 0.0000e+00.
# Epoch. 2560: loss = 4.0583e+02, acc = 0.0000e+00, valid. loss = 4.0249e+02, valid. acc. = 0.0000e+00.
# Epoch. 2570: loss = 4.0478e+02, acc = 0.0000e+00, valid. loss = 4.0307e+02, valid. acc. = 0.0000e+00.
# Epoch. 2580: loss = 4.0720e+02, acc = 0.0000e+00, valid. loss = 4.0128e+02, valid. acc. = 0.0000e+00.
# Epoch. 2590: loss = 4.0217e+02, acc = 1.1123e-04, valid. loss = 4.0457e+02, valid. acc. = 1.1123e-04.
# Epoch. 2600: loss = 4.0771e+02, acc = 1.1123e-04, valid. loss = 4.0311e+02, valid. acc. = 1.1123e-04.
# Epoch. 2610: loss = 4.0411e+02, acc = 0.0000e+00, valid. loss = 4.0227e+02, valid. acc. = 0.0000e+00.
# Epoch. 2620: loss = 4.0335e+02, acc = 0.0000e+00, valid. loss = 4.0109e+02, valid. acc. = 0.0000e+00.
# Epoch. 2630: loss = 4.0922e+02, acc = 1.1123e-04, valid. loss = 4.0326e+02, valid. acc. = 1.1123e-04.
# Epoch. 2640: loss = 4.0341e+02, acc = 0.0000e+00, valid. loss = 4.1070e+02, valid. acc. = 0.0000e+00.
# Epoch. 2650: loss = 4.0663e+02, acc = 0.0000e+00, valid. loss = 4.0602e+02, valid. acc. = 0.0000e+00.
# Epoch. 2660: loss = 4.0463e+02, acc = 0.0000e+00, valid. loss = 4.0504e+02, valid. acc. = 0.0000e+00.
# Epoch. 2670: loss = 4.1146e+02, acc = 0.0000e+00, valid. loss = 4.1515e+02, valid. acc. = 0.0000e+00.
# Epoch. 2680: loss = 4.0870e+02, acc = 0.0000e+00, valid. loss = 4.0865e+02, valid. acc. = 0.0000e+00.
# Epoch. 2690: loss = 4.1148e+02, acc = 1.1123e-04, valid. loss = 4.0559e+02, valid. acc. = 1.1123e-04.
# Epoch. 2700: loss = 4.0505e+02, acc = 0.0000e+00, valid. loss = 4.0477e+02, valid. acc. = 0.0000e+00.
# Epoch. 2710: loss = 4.0457e+02, acc = 1.1123e-04, valid. loss = 4.0509e+02, valid. acc. = 1.1123e-04.
# Epoch. 2720: loss = 4.1295e+02, acc = 0.0000e+00, valid. loss = 4.0063e+02, valid. acc. = 0.0000e+00.
# Epoch. 2730: loss = 4.0216e+02, acc = 0.0000e+00, valid. loss = 4.0604e+02, valid. acc. = 0.0000e+00.
# Epoch. 2740: loss = 4.1162e+02, acc = 0.0000e+00, valid. loss = 4.0417e+02, valid. acc. = 0.0000e+00.
# Epoch. 2750: loss = 4.0334e+02, acc = 0.0000e+00, valid. loss = 4.0088e+02, valid. acc. = 0.0000e+00.
# Epoch. 2760: loss = 4.0274e+02, acc = 0.0000e+00, valid. loss = 4.0174e+02, valid. acc. = 0.0000e+00.
# Epoch. 2770: loss = 4.0058e+02, acc = 0.0000e+00, valid. loss = 3.9887e+02, valid. acc. = 0.0000e+00.
# Epoch. 2780: loss = 4.0195e+02, acc = 0.0000e+00, valid. loss = 3.9854e+02, valid. acc. = 0.0000e+00.
# Epoch. 2790: loss = 4.0489e+02, acc = 1.1123e-04, valid. loss = 4.0413e+02, valid. acc. = 1.1123e-04.
# Epoch. 2800: loss = 4.0103e+02, acc = 0.0000e+00, valid. loss = 4.0016e+02, valid. acc. = 0.0000e+00.
# Epoch. 2810: loss = 4.0215e+02, acc = 0.0000e+00, valid. loss = 3.9792e+02, valid. acc. = 0.0000e+00.
# Epoch. 2820: loss = 4.0144e+02, acc = 0.0000e+00, valid. loss = 4.0079e+02, valid. acc. = 0.0000e+00.
# Epoch. 2830: loss = 4.0391e+02, acc = 0.0000e+00, valid. loss = 4.0017e+02, valid. acc. = 0.0000e+00.
# Epoch. 2840: loss = 4.0380e+02, acc = 0.0000e+00, valid. loss = 4.0067e+02, valid. acc. = 0.0000e+00.
# Epoch. 2850: loss = 4.0088e+02, acc = 0.0000e+00, valid. loss = 3.9798e+02, valid. acc. = 0.0000e+00.
# Epoch. 2860: loss = 4.0164e+02, acc = 0.0000e+00, valid. loss = 3.9885e+02, valid. acc. = 0.0000e+00.
# Epoch. 2870: loss = 4.0950e+02, acc = 0.0000e+00, valid. loss = 4.1963e+02, valid. acc. = 0.0000e+00.
# Epoch. 2880: loss = 4.0019e+02, acc = 0.0000e+00, valid. loss = 3.9740e+02, valid. acc. = 0.0000e+00.
# Epoch. 2890: loss = 4.0323e+02, acc = 0.0000e+00, valid. loss = 3.9823e+02, valid. acc. = 0.0000e+00.
# Epoch. 2900: loss = 3.9888e+02, acc = 0.0000e+00, valid. loss = 4.0137e+02, valid. acc. = 0.0000e+00.
# Epoch. 2910: loss = 4.0253e+02, acc = 0.0000e+00, valid. loss = 4.0631e+02, valid. acc. = 0.0000e+00.
# Epoch. 2920: loss = 4.0666e+02, acc = 0.0000e+00, valid. loss = 4.0139e+02, valid. acc. = 0.0000e+00.
# Epoch. 2930: loss = 3.9580e+02, acc = 0.0000e+00, valid. loss = 3.9663e+02, valid. acc. = 0.0000e+00.
# Epoch. 2940: loss = 4.0187e+02, acc = 0.0000e+00, valid. loss = 3.9901e+02, valid. acc. = 0.0000e+00.
# Epoch. 2950: loss = 4.0141e+02, acc = 0.0000e+00, valid. loss = 4.0270e+02, valid. acc. = 0.0000e+00.
# Epoch. 2960: loss = 4.0116e+02, acc = 0.0000e+00, valid. loss = 3.9707e+02, valid. acc. = 0.0000e+00.
# Epoch. 2970: loss = 3.9717e+02, acc = 0.0000e+00, valid. loss = 3.9637e+02, valid. acc. = 0.0000e+00.
# Epoch. 2980: loss = 4.0358e+02, acc = 0.0000e+00, valid. loss = 4.0387e+02, valid. acc. = 0.0000e+00.
# Epoch. 2990: loss = 3.9531e+02, acc = 0.0000e+00, valid. loss = 3.9547e+02, valid. acc. = 0.0000e+00.
# Epoch. 3000: loss = 4.0585e+02, acc = 0.0000e+00, valid. loss = 3.9683e+02, valid. acc. = 0.0000e+00.
# Epoch. 3010: loss = 4.1074e+02, acc = 1.1123e-04, valid. loss = 4.0377e+02, valid. acc. = 1.1123e-04.
# Epoch. 3020: loss = 4.0078e+02, acc = 0.0000e+00, valid. loss = 4.1549e+02, valid. acc. = 0.0000e+00.
# Epoch. 3030: loss = 3.9898e+02, acc = 0.0000e+00, valid. loss = 3.9629e+02, valid. acc. = 0.0000e+00.
# Epoch. 3040: loss = 3.9277e+02, acc = 1.1123e-04, valid. loss = 3.9897e+02, valid. acc. = 1.1123e-04.
# Epoch. 3050: loss = 4.0783e+02, acc = 0.0000e+00, valid. loss = 3.9598e+02, valid. acc. = 0.0000e+00.
# Epoch. 3060: loss = 4.0179e+02, acc = 0.0000e+00, valid. loss = 3.9553e+02, valid. acc. = 0.0000e+00.
# Epoch. 3070: loss = 3.9490e+02, acc = 0.0000e+00, valid. loss = 3.9841e+02, valid. acc. = 0.0000e+00.
# KeyboardInterrupt

# %%
## 学習結果の評価

# %%
o.view()

# %%
o.view()

# %%
o.view()

# %%
plot(arange(v.size),v)
plot(yidx, o.pred_func(x.reshape(-1, 1, 1, 10).astype(float32)).flatten(), c="b")
xlabel("x")
ylabel("y")
legend(["data", "predict"])

# %%
#figsize(10,10)
figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
is_first = True
for i in range(1,10,1):
    subplot(3, 3, i)
    v = zeros(1000)
    for i in range(10):
        #v += sin(pi * arange(1000) / 10) * arange(1000)[::-1]
        #v += sin(pi * arange(1000) / rand(1) / 100 + randint(0, 1000)) * arange(1000)[::-1]
        v += sin(pi * arange(1000) / randint(10, 1000) + randint(0, 1000)) * arange(1000)[::-1]
    #v2 = sin(pi * arange(1000) / 50) * arange(1000)[::-1]
    #v3 = cos(pi * arange(1000) / 250) * arange(1000)[::-1]
    #v = v + random(v.size)* arange(1000)[::-1] * 0.1
    #v = sin(pi * arange(1000) / 100) * arange(1000)[::-1] + random(v.size) * arange(1000)[::-1] * 1
    x, y, xidx, yidx = gen_dataset(v, 10) 
    #plot(xidx[0:100], x[0:100].reshape(-1,10), c="r")
    plot(arange(v.size),v, c="r",lw=5, label="Grand truth")
#plot(yidx.flatten(),y.flatten())
    plot(yidx, o.pred_func(x.reshape(-1, 1, 1, 10).astype(float32)).flatten(), c="b", label="Predict")
    plot(yidx, abs(y.flatten() - o.pred_func(x.reshape(-1, 1, 1, 10).astype(float32)).flatten()), c="g", label="Error")
    #xlim(0,300)
    
    #scatter(yidx[0:1000], o.y_train_arr[0:1000])
    xlabel("x")
    ylabel("y")
    if is_first:
        legend()
        is_first = False

# %%
line = loadtxt("/home/yu/Downloads/USDJPY.csv", delimiter=",")

# %% [markdown]
# 適当な為替データ　http://www.m2j.co.jp/market/historical.php

# %%
line.shape
# Out:
# (2684, 4)

# %%
figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
for i,l in enumerate(line.T):
    l *= 100
    subplot(2, 2, i+1)
    x, y, xidx, yidx = gen_dataset(l, 10) 
    plot(yidx, o.pred_func(x.reshape(-1, 1, 1, 10).astype(float32)).flatten())
    plot(yidx, y.astype(float32).flatten())
    plot(yidx, abs(y.flatten() - o.pred_func(x.reshape(-1, 1, 1, 10).astype(float32)).flatten()))
    legend(["Grand truth", "Predict", "error"])

# %% [markdown]
# # 処理結果を保存

# %%
o.save("result.pkl")
